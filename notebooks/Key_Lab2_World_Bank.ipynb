# %% [markdown]
# # World Bank Visualization
#
# Now we will recreate the visualization for internet usage using the world bank data.

# %% [markdown]
# ## Import the data
#
# First we import and examine the data.

# %%
import altair as alt
import pandas as pd

# %%
# Uncomment/run this line to enable Altair in the notebook (not JupyterLab):
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
world = pd.read_csv("../data/World_Bank.csv")
world.head()
# Out:
#    Region  Country  Year  \
# 0  Africa  Algeria  1960
# 1  Africa  Algeria  1961
# 2  Africa  Algeria  1962
# 3  Africa  Algeria  1963
# 4  Africa  Algeria  1964
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                           123.8892
# 1                                           124.7566
# 2                                           125.6240
# 3                                           123.5016
# 4                                           121.3792
#
#    Adult literacy rate, population 15+ years, both sexes (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    CO2 emissions (metric tons per capita)  \
# 0                                0.553764
# 1                                0.531810
# ...

# %% [markdown]
# ## Fixing the header names
#
# While communicating a lot of information, those long header names will be troublesome.  Let's import a csv with shorter and easier to use names.

# %%
world_short = pd.read_csv("../data/World_Bank_Short_Names.csv")
world_short.head()
# Out:
#    Region  Country  Year  Fertility  Internet_user_per_100  Life_expectancy
# 0  Africa  Algeria  1960      7.524                    NaN        46.135122
# 1  Africa  Algeria  1961      7.573                    NaN        46.590317
# 2  Africa  Algeria  1962      7.614                    NaN        47.045000
# 3  Africa  Algeria  1963      7.646                    NaN        47.496195
# 4  Africa  Algeria  1964      7.665                    NaN        47.941902

# %% [markdown]
# ## Plot 1 - Three Way Scatter Plot
#
# Here is the specification for the scatterplot.
#
# <img src="../images/lab_2_scatter.png">

# %%
alt.Chart(world_short).mark_point().encode(
    x = "Internet_users_per_100"
)
# Out:
# ---------------------------------------------------------------------------
# MaxRowsError                              Traceback (most recent call last)
# ~/.pyenv/versions/anaconda3-5.0.0/envs/icots/lib/python3.7/site-packages/altair/vegalite/v2/api.py in to_dict(self, *args, **kwargs)
#     312         copy = self.copy()
#     313         original_data = getattr(copy, 'data', Undefined)
# --> 314         copy.data = _prepare_data(original_data)
#     315
#     316         # We make use of two context markers:
#
# ~/.pyenv/versions/anaconda3-5.0.0/envs/icots/lib/python3.7/site-packages/altair/vegalite/v2/api.py in _prepare_data(data)
#      24         return data
#      25     elif isinstance(data, pd.DataFrame):
# ---> 26         return pipe(data, data_transformers.get())
#      27     elif isinstance(data, six.string_types):
#      28         return core.UrlData(data)
#
# ...
