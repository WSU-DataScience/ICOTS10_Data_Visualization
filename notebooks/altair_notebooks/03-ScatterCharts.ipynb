# %% [markdown]
# # Scatter Chart Examples

# %% [markdown]
# This notebook contains a number of examples of scatter-plot charts.

# %%
import altair as alt

# %%
# Uncomment/run this line to enable Altair in the classic notebook (not JupyterLab)
alt.renderers.enable('notebook')
# Out:
# RendererRegistry.enable('notebook')

# %%
from vega_datasets import data
cars = data.cars()
cars.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs       Year
# 0  chevrolet chevelle malibu    USA           3504 1970-01-01
# 1          buick skylark 320    USA           3693 1970-01-01
# 2         plymouth satellite    USA           3436 1970-01-01
# 3              amc rebel sst    USA           3433 1970-01-01
# 4                ford torino    USA           3449 1970-01-01

# %% [markdown]
# ## Dot chart

# %%
alt.Chart(cars).mark_point().encode(
    x='Horsepower',
)
# Out:
# <div class="vega-embed" id="a5441fd6-0b5d-4269-8411-911693914435"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ## Interactive Scatter chart

# %%
alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon'
).interactive()
# Out:
# <div class="vega-embed" id="9c0c0cb5-4cf3-48ce-96b8-dd3908dde1e6"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ## Bubble chart

# %%
alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    size='Acceleration'
)
# Out:
# <div class="vega-embed" id="85373ad9-cb38-43c0-9735-b1851775115d"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ## Scatter chart with color and/or shape

# %%
alt.Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    shape='Origin',
)
# Out:
# <div class="vega-embed" id="4d320786-e740-4aa9-9138-fc2c171fdde2"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ## Circle scatterchart

# %%
alt.Chart(cars).mark_circle().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
)
# Out:
# <div class="vega-embed" id="1fdf5138-1953-4bfd-a82c-eacf272dfb3e"></div>
#
# <style>
# .vega-embed .error p {
#     color: firebrick;
#     font-size: 14px;
# }
# </style>

# %% [markdown]
# ## Square scatter chart

# %%
alt.Chart(cars).mark_square().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
)
# Out:
# <VegaLite 2 object>

# %% [markdown]
# ## Text scatter chart

# %%
alt.Chart(cars).mark_text().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    text='Origin'
)
# Out:
# <VegaLite 2 object>

# %% [markdown]
# ## Tick chart

# %%
alt.Chart(cars).mark_tick().encode(
    x='Horsepower:Q',
    y='Cylinders:O',
)
# Out:
# <VegaLite 2 object>

# %% [markdown]
# ## Multi-Panel Scatter

# %%
chart = alt.Chart(cars).mark_point().encode(
    y='Horsepower:Q',
    color='Origin:N'
).interactive()

chart.encode(x='Acceleration:Q') | chart.encode(x='Displacement:Q')
# Out:
# <VegaLite 2 object>

# %% [markdown]
# ## Interactive Repeated Scatter

# %%
alt.Chart(cars).mark_point().encode(
    alt.X(alt.repeat('column'), type='quantitative'),
    alt.Y(alt.repeat('row'), type='quantitative'),
    color='Origin:N'
).properties(
    width=250,
    height=250
).repeat(
    row=['Horsepower', 'Miles_per_Gallon'],
    column=['Acceleration', 'Displacement']
).interactive()
# Out:
# <VegaLite 2 object>

# %% [markdown]
# ## Multi-Panel Scatter with Linked Brushing

# %%
brush = alt.selection_interval()

alt.Chart(cars).mark_point().encode(
    alt.X(alt.repeat('column'), type='quantitative'),
    alt.Y(alt.repeat('row'), type='quantitative'),
    color=alt.condition(brush, 'Origin:N', alt.value('gray'))
).properties(
    width=250,
    height=250,
    selection=brush
).repeat(
    row=['Horsepower', 'Miles_per_Gallon'],
    column=['Acceleration', 'Displacement']
)
# Out:
# <VegaLite 2 object>
